# %%
pip install matplotlib
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import matplotlib

# %%
matplotlib.__version__
# Out:
# '3.9.2'

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
#Draw a line in a diagram from position (0,0) to position (6,250):
x=np.array([6,10])
y=np.array([50,250])
plt.plot(x,y,0)
plt.show()

# %%
x=np.array([1,5])
y=np.array([2,5])
plt.plot(x,y,'o')
print(plt)
# Out:
# <module 'matplotlib.pyplot' from 'C:\\ProgramData\\anaconda3\\Lib\\site-packages\\matplotlib\\pyplot.py'>

# %%
z=np.array([1,3,5,7,9])
a=np.array([2,4,6,8,0])
plt.plot(z,a,'o')
print(plt)
# Out:
# <module 'matplotlib.pyplot' from 'C:\\ProgramData\\anaconda3\\Lib\\site-packages\\matplotlib\\pyplot.py'>

# %%
z=np.array([2,4,5,7,9])
a=np.array([1,9,3,5,6])
plt.plot(z,a)
print(plt)
# Out:
# <module 'matplotlib.pyplot' from 'C:\\ProgramData\\anaconda3\\Lib\\site-packages\\matplotlib\\pyplot.py'>

# %%
ypoints = np.array([300, 800, 100, 100, 500, 700])

plt.plot(ypoints)
plt.show()

# %%
y=np.array([2,4,6,7,5,3,9,0])
plt.plot(y,marker='*')
print(plt)
# Out:
# <module 'matplotlib.pyplot' from 'C:\\ProgramData\\anaconda3\\Lib\\site-packages\\matplotlib\\pyplot.py'>

# %%
y=np.array([2,4,6,7,5,3,9,0])
plt.plot(y,marker='o')
print(plt)
# Out:
# <module 'matplotlib.pyplot' from 'C:\\ProgramData\\anaconda3\\Lib\\site-packages\\matplotlib\\pyplot.py'>

# %%
y=np.array([2,4,6,7,5,3,9,0])
plt.plot(y,marker='@')
print(plt)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File C:\ProgramData\anaconda3\Lib\site-packages\matplotlib\markers.py:326, in MarkerStyle._set_marker(self, marker)
#     325 try:
# --> 326     Path(marker)
#     327     self._marker_function = self._set_vertices
#
# File C:\ProgramData\anaconda3\Lib\site-packages\matplotlib\path.py:129, in Path.__init__(self, vertices, codes, _interpolation_steps, closed, readonly)
#     101 """
#     102 Create a new path with the given vertices and codes.
#     103
#    (...)
#     127     and codes as read-only arrays.
#     128 """
# --> 129 vertices = _to_unmasked_float_array(vertices)
#     130 _api.check_shape((None, 2), vertices=vertices)
#
# File C:\ProgramData\anaconda3\Lib\site-packages\matplotlib\cbook.py:1398, in _to_unmasked_float_array(x)
#    1397 else:
# -> 1398     return np.asarray(x, float)
#
# ...

# %%
y=np.array([2,4,6,7,5,3,9,0])
plt.plot(y,linestyle='dotted')
print(plt)
# Out:
# <module 'matplotlib.pyplot' from 'C:\\ProgramData\\anaconda3\\Lib\\site-packages\\matplotlib\\pyplot.py'>

# %%
y=np.array([2,4,6,7,5,3,9,0])
plt.plot(y,ls='dashed')
print(plt)
# Out:
# <module 'matplotlib.pyplot' from 'C:\\ProgramData\\anaconda3\\Lib\\site-packages\\matplotlib\\pyplot.py'>

# %%
y=np.array([2,4,6,7,5,3,9,0])
plt.plot(y,ls='--')
print(plt)
# Out:
# <module 'matplotlib.pyplot' from 'C:\\ProgramData\\anaconda3\\Lib\\site-packages\\matplotlib\\pyplot.py'>

# %%
y=np.array([2,4,6,7,5,3,9,0])
plt.plot(y,ls='-.')
print(plt)
# Out:
# <module 'matplotlib.pyplot' from 'C:\\ProgramData\\anaconda3\\Lib\\site-packages\\matplotlib\\pyplot.py'>

# %%
y=np.array([2,4,6,7,5,3,9,0])
plt.plot(y,ls='-')
print(plt)
# Out:
# <module 'matplotlib.pyplot' from 'C:\\ProgramData\\anaconda3\\Lib\\site-packages\\matplotlib\\pyplot.py'>

# %%
y=np.array([2,4,6,7,5,3,9,0])
plt.plot(y,ls='dashed',c="r")
print(plt)
# Out:
# <module 'matplotlib.pyplot' from 'C:\\ProgramData\\anaconda3\\Lib\\site-packages\\matplotlib\\pyplot.py'>

# %%
y=np.array([2,4,6,7,5,3,9,0])
plt.plot(y,ls='dashed',c="#f633ff")
print(plt)
# Out:
# <module 'matplotlib.pyplot' from 'C:\\ProgramData\\anaconda3\\Lib\\site-packages\\matplotlib\\pyplot.py'>

# %%
y=np.array([2,4,6,7,5,3,9,0])
plt.plot(y,ls='dashed',c="yellow")
print(plt)
# Out:
# <module 'matplotlib.pyplot' from 'C:\\ProgramData\\anaconda3\\Lib\\site-packages\\matplotlib\\pyplot.py'>

# %%
y=np.array([2,4,6,7,5,3,9,0])
plt.plot(y,ls='dashed',c="yellow",linewidth=20.2)
print(plt)
# Out:
# <module 'matplotlib.pyplot' from 'C:\\ProgramData\\anaconda3\\Lib\\site-packages\\matplotlib\\pyplot.py'>

# %%
y=np.array([2,4,6,9,0])
plt.plot(y,ls='-',c="pink",linewidth=15)
print(plt)
# Out:
# <module 'matplotlib.pyplot' from 'C:\\ProgramData\\anaconda3\\Lib\\site-packages\\matplotlib\\pyplot.py'>

# %%
x1 = np.array([0, 1, 2, 3])
y1 = np.array([3, 8, 1, 10])
x2 = np.array([0, 1, 2, 3])
y2 = np.array([6, 2, 7, 11])
x3=np.array([2,3,4,4])
y3=np.array([8,3,6,1])
plt.plot(x1, y1, x2, y2,x3,y3,ls="--",color="green")
print(plt)
# Out:
# <module 'matplotlib.pyplot' from 'C:\\ProgramData\\anaconda3\\Lib\\site-packages\\matplotlib\\pyplot.py'>

# %%
x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])
plt.plot(x,y)
print(plt)
plt.xlabel("Average Pulse")
plt.ylabel("Calorie Burnage")
# Out:
# <module 'matplotlib.pyplot' from 'C:\\ProgramData\\anaconda3\\Lib\\site-packages\\matplotlib\\pyplot.py'>
# Text(0, 0.5, 'Calorie Burnage')

# %%
x = np.array([2011,2012,2013,2015,2016,2017,2018,2019])
y = np.array([12,13,15,16,17,20,22,24])
plt.plot(x,y)
print(plt)
plt.xlabel("years")
plt.ylabel("income tax rate")
# Out:
# <module 'matplotlib.pyplot' from 'C:\\ProgramData\\anaconda3\\Lib\\site-packages\\matplotlib\\pyplot.py'>
# Text(0, 0.5, 'income tax rate')

# %%
x = np.array(["mammu","tharun","ankitha","saritha","ravali","raju","ravi","praveen"])
y = np.array([12,13,15,16,17,20,12,24])
plt.plot(x,y)
print(plt)
plt.xlabel("years")
plt.ylabel("income tax rate")
# Out:
# <module 'matplotlib.pyplot' from 'C:\\ProgramData\\anaconda3\\Lib\\site-packages\\matplotlib\\pyplot.py'>
# Text(0, 0.5, 'income tax rate')

# %%
x = np.array([2011,2012,2013,2015,2016,2017,2018,2019])
y = np.array([12,13,15,16,17,20,22,24])
plt.plot(x,y)
print(plt)
plt.title("BUDGET")
plt.xlabel("years")

plt.ylabel("income tax rate")
# Out:
# <module 'matplotlib.pyplot' from 'C:\\ProgramData\\anaconda3\\Lib\\site-packages\\matplotlib\\pyplot.py'>
# Text(0, 0.5, 'income tax rate')

# %%
 x = np.array([2011,2012,2013,2015,2016,2017,2018,2019])
y = np.array([12,13,15,16,17,20,22,24])
plt.plot(x,y)
print(plt)
f1={'family':'serif','color':'red','size':20}
f2={'family':'serif','color':'red','size':20}

plt.title("BUDGET", fontdict=f1)
plt.xlabel("years",fontdict=f2)
plt.ylabel("income tax rate",fontdict=f2)
# Out:
# <module 'matplotlib.pyplot' from 'C:\\ProgramData\\anaconda3\\Lib\\site-packages\\matplotlib\\pyplot.py'>
# Text(0, 0.5, 'income tax rate')

# %%
import numpy as np
import matplotlib.pyplot as plt
x = np.array([2011,2012,2013,2015,2016,2017,2018,2019])
y = np.array([12,13,15,16,17,20,22,24])
plt.plot(x,y)
print(plt)
f1={'family':'Sans-serif','color':'blue','size':20}
f2={'family':'serif','color':'red','size':20}

plt.title("BUDGET", fontdict=f1,loc="left")
plt.xlabel("years",fontdict=f2)
plt.ylabel("income tax rate",fontdict=f2)
# Out:
# <module 'matplotlib.pyplot' from 'C:\\ProgramData\\anaconda3\\Lib\\site-packages\\matplotlib\\pyplot.py'>
# Text(0, 0.5, 'income tax rate')

# %%
x=np.array([1,3,2,5,7])
y=np.array([9,8,7,6,5])
plt.plot(x,y,c="red",ls="dashed")
plt.grid()
print(plt)
# Out:
# <module 'matplotlib.pyplot' from 'C:\\ProgramData\\anaconda3\\Lib\\site-packages\\matplotlib\\pyplot.py'>

# %%
x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])
plt.plot(x,y,ls="-.")
plt.grid(axis='x')
print(plt)
# Out:
# <module 'matplotlib.pyplot' from 'C:\\ProgramData\\anaconda3\\Lib\\site-packages\\matplotlib\\pyplot.py'>

# %%
x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])
plt.plot(x,y,ls="-.")
plt.grid(axis='y')
print(plt)
# Out:
# <module 'matplotlib.pyplot' from 'C:\\ProgramData\\anaconda3\\Lib\\site-packages\\matplotlib\\pyplot.py'>

# %%
x=np.array([1,3,5,6,7,8])
y=np.array([1,7,5,4,3,0])
plt.plot(x,y)
plt.grid(color="black",lw="2",ls="dotted")
print(plt)
# Out:
# <module 'matplotlib.pyplot' from 'C:\\ProgramData\\anaconda3\\Lib\\site-packages\\matplotlib\\pyplot.py'>

# %%
x = np.random.randint(100, size=(100))
y = np.random.randint(100, size=(100))
colors = np.random.randint(100, size=(100))

plt.scatter(x, y, c=colors, cmap='PuBuGn')

plt.colorbar()

plt.show()

# %%
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
colors = np.array([0, 10, 20, 30, 40, 45, 50, 55, 60, 70, 80, 90, 100])

plt.scatter(x, y, c=colors, cmap='viridis')

plt.colorbar()

plt.show()

# %%
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
sizes = np.array([20,50,100,200,500,1000,60,90,10,300,600,800,75])

plt.scatter(x, y, s=sizes)

plt.show()

# %%
x=np.array(["A","B","C","D"])
y=np.array([100,200,300,400])

plt.bar(x,y)
print(plt)
# Out:
# <module 'matplotlib.pyplot' from 'C:\\ProgramData\\anaconda3\\Lib\\site-packages\\matplotlib\\pyplot.py'>

# %%
x=np.array(["A","B","C","D"])
y=np.array([100,200,300,400])

plt.barh(x,y)
print(plt)
# Out:
# <module 'matplotlib.pyplot' from 'C:\\ProgramData\\anaconda3\\Lib\\site-packages\\matplotlib\\pyplot.py'>

# %%
x=np.array(["A","B","C","D"])
y=np.array([100,200,300,400])

plt.bar(x,y,color="pink",width=0.1)
print(plt)
# Out:
# <module 'matplotlib.pyplot' from 'C:\\ProgramData\\anaconda3\\Lib\\site-packages\\matplotlib\\pyplot.py'>

# %%
x=np.array(["A","B","C","D"])
y=np.array([100,200,300,400])

plt.barh(x,y,color="black",height=0.1)
print(plt)
# Out:
# <module 'matplotlib.pyplot' from 'C:\\ProgramData\\anaconda3\\Lib\\site-packages\\matplotlib\\pyplot.py'>

# %%
x=np.array([56,34,23,12])
plt.pie(x)
print(plt)
# Out:
# <module 'matplotlib.pyplot' from 'C:\\ProgramData\\anaconda3\\Lib\\site-packages\\matplotlib\\pyplot.py'>

# %%
x=np.array([56,34,23,12])
mylabels=["mammu","tharun","ankitha","ravali"]
plt.pie(x,labels=mylabels)
print(plt)
# Out:
# <module 'matplotlib.pyplot' from 'C:\\ProgramData\\anaconda3\\Lib\\site-packages\\matplotlib\\pyplot.py'>

# %%
x=np.array([56,34,23,12])
mylabels=["mammu","tharun","ankitha","ravali"]
plt.pie(x,labels=mylabels,startangle=90)
print(plt)
# Out:
# <module 'matplotlib.pyplot' from 'C:\\ProgramData\\anaconda3\\Lib\\site-packages\\matplotlib\\pyplot.py'>

# %%
x=np.array([56,34,23,12])
mylabels=["mammu","tharun","ankitha","ravali"]
myexplode=(0.2,0,0,0)
plt.pie(x,labels=mylabels,explode=myexplode)

print(plt)
# Out:
# <module 'matplotlib.pyplot' from 'C:\\ProgramData\\anaconda3\\Lib\\site-packages\\matplotlib\\pyplot.py'>

# %%
x=np.array([56,34,23,12])
mylabels=["mammu","tharun","ankitha","ravali"]
myexplode=(0.2,0,0,0)
plt.pie(x,labels=mylabels,explode=myexplode,shadow=True)

print(plt)
# Out:
# <module 'matplotlib.pyplot' from 'C:\\ProgramData\\anaconda3\\Lib\\site-packages\\matplotlib\\pyplot.py'>

# %%
x=np.array([56,34,23,12])
mylabels=["mammu","tharun","ankitha","ravali"]
myexplode=(0.2,0,0,0)
myclors=("pink","yellow","blue","black")
plt.pie(x,labels=mylabels,explode=myexplode,colors=myclors)

print(plt)
# Out:
# <module 'matplotlib.pyplot' from 'C:\\ProgramData\\anaconda3\\Lib\\site-packages\\matplotlib\\pyplot.py'>

# %%
x=np.array([56,34,23,12])
mylabels=["mammu","tharun","ankitha","ravali"]
myexplode=(0.2,0,0,0)
plt.pie(x,labels=mylabels,explode=myexplode)
plt.legend(title="STUDENTS NAMES")
print(plt)
# Out:
# <module 'matplotlib.pyplot' from 'C:\\ProgramData\\anaconda3\\Lib\\site-packages\\matplotlib\\pyplot.py'>

# %%
import numpy as np
import pandas as pd
import warnings
warnings.filterwarnings("ignore")

# %%
dff=pd.DataFrame({'Key':['A','B','C','A','B','C'],
                 'data':range(1,7)})
dff
# Out:
#   Key  data
# 0   A     1
# 1   B     2
# 2   C     3
# 3   A     4
# 4   B     5
# 5   C     6

# %%
dff.Key.unique()
# Out:
# array(['A', 'B', 'C'], dtype=object)

# %%
dff.groupby('Key').sum()
# Out:
#      data
# Key
# A       5
# B       7
# C       9

# %%
dff.groupby('Key').mean()
# Out:
#      data
# Key
# A     2.5
# B     3.5
# C     4.5

# %%
dff.groupby('Key').max()
# Out:
#      data
# Key
# A       4
# B       5
# C       6

# %%
dff.groupby('Key').describe()
# Out:
#      data
#     count mean      std  min   25%  50%   75%  max
# Key
# A     2.0  2.5  2.12132  1.0  1.75  2.5  3.25  4.0
# B     2.0  3.5  2.12132  2.0  2.75  3.5  4.25  5.0
# C     2.0  4.5  2.12132  3.0  3.75  4.5  5.25  6.0

# %%
titanic=pd.read_csv(r"C:\Users\Mounika\Downloads\titanic.csv")
titanic.shape
# Out:
# (891, 12)

# %%
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
titanic.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
titanic.groupby('Sex')['Survived'].mean()
# Out:
# Sex
# female    0.742038
# male      0.188908
# Name: Survived, dtype: float64

# %%
titanic.groupby('Pclass')['Survived'].mean()
# Out:
# Pclass
# 1    0.629630
# 2    0.472826
# 3    0.242363
# Name: Survived, dtype: float64

# %%
titanic.groupby(['Sex','Pclass'])['Survived'].mean()
# Out:
# Sex     Pclass
# female  1         0.968085
#         2         0.921053
#         3         0.500000
# male    1         0.368852
#         2         0.157407
#         3         0.135447
# Name: Survived, dtype: float64

# %%
type(titanic.groupby(['Sex','Pclass'])['Survived'].mean())
# Out:
# pandas.core.series.Series

# %%
titanic.groupby(['Sex','Pclass'])['Survived'].mean().unstack()
# Out:
# Pclass         1         2         3
# Sex
# female  0.968085  0.921053  0.500000
# male    0.368852  0.157407  0.135447

# %%
titanic.pivot_table('Survived',index='Sex',columns='Pclass')
# Out:
# Pclass         1         2         3
# Sex
# female  0.968085  0.921053  0.500000
# male    0.368852  0.157407  0.135447

# %%
import seaborn as sns

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
tips=sns.load_dataset('tips')
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
tips.tail()
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2

# %%
tips.sex.value_counts()
# Out:
# sex
# Male      157
# Female     87
# Name: count, dtype: int64

# %%
tips.sex.value_counts(normalize=True)
# Out:
# sex
# Male      0.643443
# Female    0.356557
# Name: proportion, dtype: float64

# %%
tips.smoker.value_counts()
# Out:
# smoker
# No     151
# Yes     93
# Name: count, dtype: int64

# %%
tips.smoker.value_counts(normalize=True)
# Out:
# smoker
# No     0.618852
# Yes    0.381148
# Name: proportion, dtype: float64

# %%
#Use groupby and Give me data of Gender(sex) where total bill and tip should be displayed
tips.groupby(['sex'])['total_bill','tip'].sum()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[52], line 2
#       1 #Use groupby and Give me data of Gender(sex) where total bill and tip should be displayed
# ----> 2 tips.groupby(['sex'])['total_bill','tip'].sum()
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\groupby\generic.py:1947, in DataFrameGroupBy.__getitem__(self, key)
#    1943 # per GH 23566
#    1944 if isinstance(key, tuple) and len(key) > 1:
#    1945     # if len == 1, then it becomes a SeriesGroupBy and this is actually
#    1946     # valid syntax, so don't raise
# -> 1947     raise ValueError(
#    1948         "Cannot subset columns with a tuple with more than one element. "
#    1949         "Use a list instead."
#    1950     )
#    1951 return super().__getitem__(key)
#
# ValueError: Cannot subset columns with a tuple with more than one element. Use a list instead.
